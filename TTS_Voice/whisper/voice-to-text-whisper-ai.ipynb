# %% [markdown]
# # Install Whisper

# %%
# install openai's whisper
# !pip install git+https://github.com/openai/whisper.git

# update the packages
# !sudo apt update && sudo apt install ffmpeg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-y7jlryzv
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-y7jlryzv
#   Resolved https://github.com/openai/whisper.git to commit 7858aa9c08d98f75575035ecd6481f462d66ca27
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 78.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 98.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 22.5 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20230124-py3-none-any.whl size=1179424 sha256=248e6e5c8044340d5fde8772b57cbd9fd434c7b7d43fe1dae1ab67d863cf625b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-10kzggjt/wheels/a7/70/18/b7693c07b1d18b3dafb328f5d0496aa0d41a9c09ef332fd8e6
# ...

# %% [markdown]
# # Upload .WAV file and change the directory, then run it 👌

# %%
# Run Whisper AI:
# !whisper /content/BodyScan1Residential.wav --model large-v2

# Additional arguments:
# !whisper -h --verbose
# Out:
# tcmalloc: large alloc 3087007744 bytes == 0xbb96000 @  0x7f5558956680 0x7f5558977824 0x5f97c1 0x649901 0x5c43c6 0x4f327e 0x64e618 0x505163 0x56bbe1 0x5f5ee6 0x56bab6 0x569d8a 0x5f60c3 0x56cc92 0x5f5ee6 0x56bab6 0x569d8a 0x68e267 0x67d9b1 0x67da2f 0x67dad1 0x67fbf7 0x6b8082 0x6b840d 0x7f5558755083 0x5faa2e
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/whisper/audio.py", line 42, in load_audio
#     ffmpeg.input(file, threads=0)
#   File "/usr/local/lib/python3.8/dist-packages/ffmpeg/_run.py", line 325, in run
#     raise Error('ffmpeg', out, err)
# ffmpeg._run.Error: ffmpeg error (see stderr output for detail)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/whisper", line 8, in <module>
#     sys.exit(cli())
#   File "/usr/local/lib/python3.8/dist-packages/whisper/transcribe.py", line 314, in cli
# ...
