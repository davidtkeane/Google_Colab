# %% [markdown]
# # Install Whisper

# %%
# install openai's whisper
# !pip install git+https://github.com/openai/whisper.git

# update the packages
# !sudo apt update && sudo apt install ffmpeg
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-vt00akmm
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-vt00akmm
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 16.9 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20231117-py3-none-any.whl size=802825 sha256=e124028a7bf94e1ec412111b0df3ac81aaae059ee3deb356252997443c8bd598
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hf9z__vt/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# ...
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# ...

# %% [markdown]
# # Upload .WAV file and change the directory, then run it 👌

# %%
# Run Whisper AI:
# !whisper /content/BodyScan1-Residential.wav --model large-v2

# Additional arguments:
# !whisper -h --verbose --language en
# Out:
# tcmalloc: large alloc 3087007744 bytes == 0xa96c000 @  0x7f6bc203e680 0x7f6bc205f824 0x5f97c1 0x649901 0x5c43c6 0x4f327e 0x64e618 0x505163 0x56bbe1 0x5f5ee6 0x56bab6 0x569d8a 0x5f60c3 0x56cc92 0x5f5ee6 0x56bab6 0x569d8a 0x68e267 0x67d9b1 0x67da2f 0x67dad1 0x67fbf7 0x6b8082 0x6b840d 0x7f6bc1e3d083 0x5faa2e
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.800 --> 00:03.760]  Stirring bell
# [00:07.280 --> 00:09.960]  Stirring bell
# [00:09.960 --> 00:39.680]  So welcoming you to this body scan practice and inviting you to just take a
# [00:39.680 --> 00:49.440]  moment sensing the body lying here or perhaps sitting, feeling the contact of
# [00:49.440 --> 01:01.000]  parts of the body in contact with the floor, the seat, allowing your arms by
# [01:01.000 --> 01:12.640]  your side or whatever feels comfortable for you or reasonably and if you would
# ...
